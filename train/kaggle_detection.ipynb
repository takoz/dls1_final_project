# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import os
import torch
import matplotlib.pyplot as plt
import numpy as np

from torchvision import transforms
from torchvision.utils import draw_bounding_boxes
from ultralytics import YOLO
import albumentations as A
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
DATASET_C2_PATH = '/kaggle/working/bonefracture_converted_obb_no_humerus'
CONFIG_C2_PATH = os.path.join(DATASET_C2_PATH, 'data.yaml')

# %%
custom_transforms = [
  A.ToGray(p=0.1),
  A.CLAHE(p=1.0),
  A.RandomBrightnessContrast(p=0.1),
  A.ElasticTransform(p=0.01),
  A.Sharpen(p=0.1)
]

model_yolo26s = YOLO("yolo26s-obb.pt")

results = model_yolo26s.train(
  data=CONFIG_C2_PATH,
  imgsz=1024,
  seed=10200,
  cos_lr=True,
  pose=0,
  flipud=0.5,
  mosaic=0,
  augmentations=custom_transforms,
  patience=50,
  epochs=100,
  degrees=90,
  device=[0, 1]
)
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
#                                                        CUDA:1 (Tesla T4, 14912MiB)
# ...

# %%
custom_transforms = [
  A.ToGray(p=0.1),
  A.CLAHE(p=1.0),
  A.RandomBrightnessContrast(p=0.1),
  A.ElasticTransform(p=0.01),
  A.Sharpen(p=0.1)
]

model_yolo26n = YOLO("yolo26n-obb.pt")

results = model_yolo26n.train(
  data=CONFIG_C2_PATH,
  imgsz=1024,
  seed=10200,
  cos_lr=True,
  pose=0,
  flipud=0.5,
  mosaic=0,
  augmentations=custom_transforms,
  patience=20,
  epochs=50,
  degrees=90,
  device=[0, 1]
)
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
#                                                        CUDA:1 (Tesla T4, 14912MiB)
# ...

# %%
custom_transforms = [
  A.ToGray(p=0.1),
  A.CLAHE(p=1.0),
  A.RandomBrightnessContrast(p=0.1),
  A.ElasticTransform(p=0.01),
  A.Sharpen(p=0.1)
]

model_yolo8n = YOLO("yolov8n-obb.pt")

results = model_yolo8n.train(
  data=CONFIG_C2_PATH,
  imgsz=1024,
  seed=10200,
  cos_lr=True,
  pose=0,
  flipud=0.5,
  mosaic=0,
  augmentations=custom_transforms,
  patience=20,
  epochs=50,
  degrees=90,
  device=[0, 1]
)
# Out:
# ...
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
#                                                        CUDA:1 (Tesla T4, 14912MiB)
# ...

# %%
model_yolo26s = YOLO("/kaggle/working/runs/obb/train-15/weights/best.pt")

metrics = model_yolo26s.val(data=CONFIG_C2_PATH, split="test")
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26s-obb summary (fused): 132 layers, 9,753,489 parameters, 0 gradients, 21.5 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 23.6±18.0 MB/s, size: 37.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/working/bonefracture_converted_obb_no_humerus/test/labels... 366 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 366/366 711.2it/s 0.5s0.0s
# val: New cache created: /kaggle/working/bonefracture_converted_obb_no_humerus/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 1.9it/s 12.0s0.5s
#                    all        366        416      0.969      0.907      0.946      0.773
#         elbow positive         62         68      0.952      0.873      0.909      0.762
# ...

# %%
model_yolo26n = YOLO("/kaggle/working/runs/obb/train/weights/best.pt")

metrics = model_yolo26n.val(data=CONFIG_C2_PATH, split="test")
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26n-obb summary (fused): 132 layers, 2,447,577 parameters, 0 gradients, 5.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1296.3±358.0 MB/s, size: 37.3 KB)
# val: Scanning /kaggle/working/bonefracture_converted_obb_no_humerus/test/labels.cache... 366 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 366/366 118.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 3.1it/s 7.4s0.3s
#                    all        366        416      0.902      0.784      0.885      0.584
#         elbow positive         62         68      0.936      0.858      0.938      0.617
#       fingers positive         88        107       0.82      0.683      0.806      0.458
#       forearm fracture         64         70      0.951      0.836      0.885      0.593
# ...

# %%
model_yolov8n = YOLO("/kaggle/working/runs/obb/train-2/weights/best.pt")

metrics = model_yolov8n.val(data=CONFIG_C2_PATH, split="test")
# Out:
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLOv8n-obb summary (fused): 82 layers, 3,078,389 parameters, 0 gradients, 8.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1159.1±322.4 MB/s, size: 37.4 KB)
# val: Scanning /kaggle/working/bonefracture_converted_obb_no_humerus/test/labels.cache... 366 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 366/366 127.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 3.0it/s 7.7s0.3s
#                    all        366        416      0.815      0.735      0.814      0.522
#         elbow positive         62         68      0.728      0.747      0.822      0.497
#       fingers positive         88        107      0.679      0.634      0.689      0.393
#       forearm fracture         64         70      0.884      0.743      0.849      0.556
# ...
